# %% [markdown]
# # WeRateDogs: Wrangle and Analysis

# %%
import pandas as pd
import numpy as np
import requests
import tweepy
import json
import timeit
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Gathering

# %% [markdown]
# ### Manually

# %%
#Read the twitter data provided by Udacity
df_twitter = pd.read_csv ('twitter-archive-enhanced.csv')
df_twitter.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### Programatically

# %%
#Download of image predictions file with requests library
image_url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(image_url)

with open('image_predictions.tsv', 'wb') as f:
    f.write(response.content)

# %%
#Read the image prediction data
df_predictions = pd.read_csv('image_predictions.tsv', sep='\t')
df_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
# Save df_predictions in a csv file
df_predictions.to_csv('image_predictions.csv', index=False)

# %% [markdown]
# ### API

# %%
#Introduction of Twitter's keys
consumer_key = 'Secret-key'
consumer_secret = 'Secret-key'
access_token = 'Secret-key'
access_secret = 'Secret-key'

#Connection with the Twitter's API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
#Create a list of Id's from the file df_twitter
tweet_id_list = df_twitter['tweet_id'].tolist()

# %%
#Get data from the Twitter's API
start = timeit.timeit()

tweet_errors = []
with open('tweet_json.txt', 'w') as f:
    for i in tweet_id_list:       
        try:
            tweet_row = api.get_status(i, tweet_mode = 'extended', wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
            json.dump(tweet_row._json, f)
            f.write('\n')
            
        except Exception as ex:
            print(ex)
            print(f'Error_tweet_id {i}')
            tweet_errors.append(i)
            continue

end = timeit.timeit()
print(end - start)
# Out:
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 888202515573088257
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 873697596434513921
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 872668790621863937
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 872261713294495745
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 869988702071779329
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 866816280283807744
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 861769973181624320
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 856602993587888130
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 851953902622658560
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error_tweet_id 845459076796616705
# ...

# %%
# Read tweets in json format from tweet_json.txt and convert it to a Dataframe
json_list = []
with open('tweet_json.txt', 'r') as file:
    for row in file:
        try:
            tweet = json.loads(row)
            json_list.append({'tweet_id': tweet['id'], 'retweet_count': tweet['retweet_count'], 
                              'favorite_count': tweet['favorite_count']})
          
        except Exception as ex:
            print(ex)
            continue

df_api = pd.DataFrame(json_list)
df_api.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           7455           35310
# 1  892177421306343426           5535           30551
# 2  891815181378084864           3661           22994
# 3  891689557279858688           7625           38592
# 4  891327558926688256           8221           36878

# %%
# Save df_api in a csv file
df_api.to_csv('tweet_json.csv', encoding = 'utf-8', index=False)

# %% [markdown]
# ## Assesing

# %% [markdown]
# ### df_twitter

# %%
df_twitter
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
df_twitter.sort_values('name', ascending=False)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 773   776249906839351296                    NaN                  NaN
# 1031  745422732645535745                    NaN                  NaN
# 819   770655142660169732                    NaN                  NaN
# 1097  736225175608430592                    NaN                  NaN
# 1385  700747788515020802                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1327  705975130514706432                    NaN                  NaN
# 1933  674019345211760640                    NaN                  NaN
# 938   753294487569522689                    NaN                  NaN
# 1021  746726898085036033                    NaN                  NaN
# 1035  744995568523612160                    NaN                  NaN
#
#                       timestamp  \
# 773   2016-09-15 02:42:54 +0000
# 1031  2016-06-22 01:06:43 +0000
# 819   2016-08-30 16:11:18 +0000
# ...

# %%
df_twitter.name.value_counts()
# Out:
# None         745
# a             55
# Charlie       12
# Lucy          11
# Oliver        11
#             ...
# Genevieve      1
# Karma          1
# Odin           1
# Kevon          1
# Eevee          1
# Name: name, Length: 957, dtype: int64

# %%
df_twitter[df_twitter.name == 'a']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1017  746872823977771008                    NaN                  NaN
# 1049  743222593470234624                    NaN                  NaN
# 1193  717537687239008257                    NaN                  NaN
# 1207  715733265223708672                    NaN                  NaN
# 1340  704859558691414016                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1361  703079050210877440                    NaN                  NaN
# 1368  702539513671897089                    NaN                  NaN
# ...

# %%
df_twitter[df_twitter.name == 'None']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 5     2017-07-29 00:08:17 +0000
# 7     2017-07-28 00:22:40 +0000
# 12    2017-07-25 01:55:32 +0000
# ...

# %%
wrong_names = df_twitter.name.str.match(r"\b[^A-Z]\w+")
df_twitter[wrong_names]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 22    887517139158093824                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# 169   859196978902773760                    NaN                  NaN
# 193   855459453768019968                    NaN                  NaN
# 335   832645525019123713                    NaN                  NaN
# 369   828650029636317184                    NaN                  NaN
# 542   806219024703037440                    NaN                  NaN
# 682   788552643979468800                    NaN                  NaN
# 759   778396591732486144                    NaN                  NaN
# 773   776249906839351296                    NaN                  NaN
# 819   770655142660169732                    NaN                  NaN
# 822   770093767776997377                    NaN                  NaN
# 852   765395769549590528                    NaN                  NaN
# ...

# %%
df_twitter[wrong_names].name.value_counts()
# Out:
# the             8
# an              7
# very            5
# just            4
# quite           4
# one             4
# mad             2
# not             2
# getting         2
# actually        2
# incredibly      1
# such            1
# old             1
# his             1
# light           1
# unacceptable    1
# this            1
# space           1
# infuriating     1
# all             1
# officially      1
# by              1
# life            1
# my              1
# Name: name, dtype: int64

# %%
df_twitter[df_twitter.name == 'space']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2030  671789708968640512                    NaN                  NaN
#
#                       timestamp  \
# 2030  2015-12-01 20:35:22 +0000
#
#                                                  source  \
# 2030  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2030  This is space pup. He's very confused. Tries t...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2030                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2030  https://twitter.com/dog_rates/status/671789708...                13
#
#       rating_denominator   name doggo floofer pupper puppo
# 2030                  10  space  None    None   None  None

# %%
df_twitter[df_twitter.name == 'quite']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 118   869988702071779329                    NaN                  NaN
# 169   859196978902773760                    NaN                  NaN
# 193   855459453768019968                    NaN                  NaN
# 2326  666411507551481857                    NaN                  NaN
#
#                       timestamp  \
# 118   2017-05-31 18:47:24 +0000
# 169   2017-05-02 00:04:57 +0000
# 193   2017-04-21 16:33:22 +0000
# 2326  2015-11-17 00:24:19 +0000
#
#                                                  source  \
# 118   <a href="http://twitter.com/download/iphone" r...
# 169   <a href="http://twitter.com/download/iphone" r...
# 193   <a href="http://twitter.com/download/iphone" r...
# 2326  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 118   RT @dog_rates: We only rate dogs. This is quit...         8.591970e+17
# ...

# %%
df_twitter[df_twitter.name == 'very']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 773   776249906839351296                    NaN                  NaN
# 819   770655142660169732                    NaN                  NaN
# 1031  745422732645535745                    NaN                  NaN
# 1097  736225175608430592                    NaN                  NaN
# 1385  700747788515020802                    NaN                  NaN
#
#                       timestamp  \
# 773   2016-09-15 02:42:54 +0000
# 819   2016-08-30 16:11:18 +0000
# 1031  2016-06-22 01:06:43 +0000
# 1097  2016-05-27 15:58:54 +0000
# 1385  2016-02-19 18:24:26 +0000
#
#                                                  source  \
# 773   <a href="http://twitter.com/download/iphone" r...
# 819   <a href="http://twitter.com/download/iphone" r...
# 1031  <a href="http://twitter.com/download/iphone" r...
# 1097  <a href="http://twitter.com/download/iphone" r...
# 1385  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_twitter[df_twitter.name == 'an']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 759   778396591732486144                    NaN                  NaN
# 1025  746369468511756288                    NaN                  NaN
# 1362  703041949650034688                    NaN                  NaN
# 2204  668636665813057536                    NaN                  NaN
# 2333  666337882303524864                    NaN                  NaN
# 2335  666287406224695296                    NaN                  NaN
# 2349  666051853826850816                    NaN                  NaN
#
#                       timestamp  \
# 759   2016-09-21 00:53:04 +0000
# 1025  2016-06-24 15:48:42 +0000
# 1362  2016-02-26 02:20:37 +0000
# 2204  2015-11-23 03:46:18 +0000
# 2333  2015-11-16 19:31:45 +0000
# 2335  2015-11-16 16:11:11 +0000
# 2349  2015-11-16 00:35:11 +0000
#
#                                                  source  \
# 759   <a href="http://twitter.com/download/iphone" r...
# ...

# %%
df_twitter[df_twitter.name == 'incredibly']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 542  806219024703037440                    NaN                  NaN
#
#                      timestamp  \
# 542  2016-12-06 19:29:28 +0000
#
#                                                 source  \
# 542  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 542  We only rate dogs. Please stop sending in non-...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 542                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 542  https://twitter.com/dog_rates/status/806219024...                11
#
#      rating_denominator        name doggo floofer pupper puppo
# 542                  10  incredibly  None    None   None  None

# %%
df_twitter[df_twitter.name == 'very']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 773   776249906839351296                    NaN                  NaN
# 819   770655142660169732                    NaN                  NaN
# 1031  745422732645535745                    NaN                  NaN
# 1097  736225175608430592                    NaN                  NaN
# 1385  700747788515020802                    NaN                  NaN
#
#                       timestamp  \
# 773   2016-09-15 02:42:54 +0000
# 819   2016-08-30 16:11:18 +0000
# 1031  2016-06-22 01:06:43 +0000
# 1097  2016-05-27 15:58:54 +0000
# 1385  2016-02-19 18:24:26 +0000
#
#                                                  source  \
# 773   <a href="http://twitter.com/download/iphone" r...
# 819   <a href="http://twitter.com/download/iphone" r...
# 1031  <a href="http://twitter.com/download/iphone" r...
# 1097  <a href="http://twitter.com/download/iphone" r...
# 1385  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
df_twitter.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
df_twitter[df_twitter['retweeted_status_id'].notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1023  746521445350707200                    NaN                  NaN
# 1043  743835915802583040                    NaN                  NaN
# 1242  711998809858043904                    NaN                  NaN
# 2259  667550904950915073                    NaN                  NaN
# 2260  667550882905632768                    NaN                  NaN
#
#                       timestamp  \
# 19    2017-07-21 01:02:36 +0000
# 32    2017-07-15 02:45:48 +0000
# 36    2017-07-13 01:35:06 +0000
# ...

# %%
df_twitter[df_twitter['in_reply_to_status_id'].notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# ...                  ...                    ...                  ...
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2149  669684865554620416           6.693544e+17         4.196984e+09
# 2169  669353438988365824           6.678065e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 2298  667070482143944705           6.670655e+17         4.196984e+09
#
#                       timestamp  \
# 30    2017-07-15 16:51:35 +0000
# 55    2017-07-02 21:58:53 +0000
# 64    2017-06-27 12:14:36 +0000
# ...

# %%
sum(df_twitter.duplicated())
# Out:
# 0

# %% [markdown]
# ### Predictions

# %%
df_predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
df_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_predictions.p1.value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# rapeseed                1
# orange                  1
# washer                  1
# microwave               1
# sandbar                 1
# Name: p1, Length: 378, dtype: int64

# %%
sum(df_predictions.duplicated())
# Out:
# 0

# %% [markdown]
# - Everything seems fairly clean in the image prediction dataframe

# %% [markdown]
# ### API

# %%
df_api
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           7455           35310
# 1     892177421306343426           5535           30551
# 2     891815181378084864           3661           22994
# 3     891689557279858688           7625           38592
# 4     891327558926688256           8221           36878
# ...                  ...            ...             ...
# 2326  666049248165822465             39              95
# 2327  666044226329800704            124             263
# 2328  666033412701032449             39             108
# 2329  666029285002620928             41             118
# 2330  666020888022790149            447            2357
#
# [2331 rows x 3 columns]

# %%
df_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2331 non-null   int64
#  1   retweet_count   2331 non-null   int64
#  2   favorite_count  2331 non-null   int64
# dtypes: int64(3)
# memory usage: 54.8 KB

# %%
sum(df_api.duplicated())
# Out:
# 0

# %% [markdown]
# - Everything seems fairly clean in the api dataframe

# %% [markdown]
# ### Quality
# #### `df_twitter`
# - Lines with in_reply not null are replies
# - Lines with retweeted status not null are retweets
# - Names very, quite, incredibly, infuriating and his are not dogs
# - Nan names dogs with name None, a, one, ...
# - Timestamp column is a string
# - There should be an extra column showing the actual rating without differences in the denominators
# - Missing expanded urls (not possible to solve)
# - Tweet id 765395769549590528 name is Zoey
# - Tweet_id 878604707211726852 name is Martha
# - Source column has html tags
#
# ### Tideness
#
# - **`df_twitter`**: Columns doggo, ploofer, pupper, puppo should be only one
# - **``df_twitter and df_api``** should be only one table

# %% [markdown]
# ## Clean

# %%
# Make copies of each dataset
df_twitter_clean = df_twitter.copy()
df_predictions_clean = df_predictions.copy()
df_api_clean = df_api.copy()

# %% [markdown]
# ### Tideness

# %% [markdown]
# - **df_twitter: Columns doggo, ploofer, pupper, puppo should be only one**

# %% [markdown]
# #### Define

# %% [markdown]
# Melt the columns doggo, floofer, pupper and puppo into one single column named stage

# %% [markdown]
# #### Code

# %%
df_twitter_stage = pd.melt(df_twitter_clean, ['tweet_id'], value_vars = ['doggo', 'floofer', 'pupper', 'puppo'],
                     value_name = 'stage')

# %%
df_twitter_stage
# Out:
#                 tweet_id variable stage
# 0     892420643555336193    doggo  None
# 1     892177421306343426    doggo  None
# 2     891815181378084864    doggo  None
# 3     891689557279858688    doggo  None
# 4     891327558926688256    doggo  None
# ...                  ...      ...   ...
# 9419  666049248165822465    puppo  None
# 9420  666044226329800704    puppo  None
# 9421  666033412701032449    puppo  None
# 9422  666029285002620928    puppo  None
# 9423  666020888022790149    puppo  None
#
# [9424 rows x 3 columns]

# %%
df_twitter_stage.stage.value_counts()
# Out:
# None       9030
# pupper      257
# doggo        97
# puppo        30
# floofer      10
# Name: stage, dtype: int64

# %%
#Remove all rows with a None value in the column stage
df_twitter_stage = df_twitter_stage[df_twitter_stage.stage != 'None']

# %%
#Drop the column 'variable'
df_twitter_stage = df_twitter_stage.drop(['variable'], axis = 1)

# %%
#Join the new column stage with the df_twitter_clean table
df_twitter_clean = pd.merge(df_twitter_clean, df_twitter_stage, on=['tweet_id'], how='left')

# %%
#Remove the columns doggo, floofer, pupper and puppo from f_twitter_clean table
df_twitter_clean = df_twitter_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis = 1)

# %% [markdown]
# #### Test

# %%
df_twitter_clean[df_twitter_clean.stage == 'floofer']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 46    883360690899218434                    NaN                  NaN
# 202   854010172552949760                    NaN                  NaN
# 588   800388270626521089                    NaN                  NaN
# 782   776218204058357768                    NaN                  NaN
# 996   749317047558017024                    NaN                  NaN
# 1034  746542875601690625                    NaN                  NaN
# 1104  737445876994609152                    NaN                  NaN
# 1123  733822306246479872                    NaN                  NaN
# 1548  689993469801164801                    NaN                  NaN
# 1628  685307451701334016                    NaN                  NaN
#
#                       timestamp  \
# 46    2017-07-07 16:22:55 +0000
# 202   2017-04-17 16:34:26 +0000
# 588   2016-11-20 17:20:08 +0000
# 782   2016-09-15 00:36:55 +0000
# 996   2016-07-02 19:01:20 +0000
# ...

# %%
df_twitter_clean[df_twitter_clean.tweet_id == 685307451701334016]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1628  685307451701334016                    NaN                  NaN
#
#                       timestamp  \
# 1628  2016-01-08 03:50:03 +0000
#
#                                                  source  \
# 1628  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1628  Say hello to Petrick. He's an Altostratus Floo...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1628                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1628  https://twitter.com/dog_rates/status/685307451...                11
#
#       rating_denominator     name    stage
# 1628                  10  Petrick  floofer

# %%
df_twitter[df_twitter.tweet_id == 685307451701334016]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1614  685307451701334016                    NaN                  NaN
#
#                       timestamp  \
# 1614  2016-01-08 03:50:03 +0000
#
#                                                  source  \
# 1614  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1614  Say hello to Petrick. He's an Altostratus Floo...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1614                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1614  https://twitter.com/dog_rates/status/685307451...                11
#
#       rating_denominator     name doggo  floofer pupper puppo
# 1614                  10  Petrick  None  floofer   None  None

# %% [markdown]
# The stage column of the df_twitter_clean table matches the values of the dirty table df_twitter

# %% [markdown]
# - **df_twitter and df_api should be only one table**

# %% [markdown]
# #### Define

# %% [markdown]
# Merge tables df_twitter_clean and df_api_clean through left join

# %% [markdown]
# #### Code

# %%
df_master = pd.merge(df_twitter_clean, df_api_clean, on=['tweet_id'], how='left')

# %% [markdown]
# #### Test

# %%
df_master
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2365  666049248165822465                    NaN                  NaN
# 2366  666044226329800704                    NaN                  NaN
# 2367  666033412701032449                    NaN                  NaN
# 2368  666029285002620928                    NaN                  NaN
# 2369  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
len(df_twitter_clean)
# Out:
# 2370

# %%
len(df_api_clean)
# Out:
# 2331

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2370 entries, 0 to 2369
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2370 non-null   int64
#  1   in_reply_to_status_id       79 non-null     float64
#  2   in_reply_to_user_id         79 non-null     float64
#  3   timestamp                   2370 non-null   object
#  4   source                      2370 non-null   object
#  5   text                        2370 non-null   object
#  6   retweeted_status_id         183 non-null    float64
#  7   retweeted_status_user_id    183 non-null    float64
#  8   retweeted_status_timestamp  183 non-null    object
#  9   expanded_urls               2311 non-null   object
#  10  rating_numerator            2370 non-null   int64
#  11  rating_denominator          2370 non-null   int64
#  12  name                        2370 non-null   object
# ...

# %% [markdown]
# The size of the table it's ok, but the datatypes of retweet_count and favorite_count changed to float. It's not possible to change it since int64 type does not accept NaN values.

# %% [markdown]
# ### Quality

# %% [markdown]
# - **Lines with in_reply not null are replies**

# %% [markdown]
# #### Define

# %% [markdown]
# Drop the non-null rows in the columns 'in_reply_to_status_id' and 'in_reply_to_user_id' and then delete those same columns

# %% [markdown]
# #### Code

# %%
df_master = df_master[df_master.in_reply_to_status_id.isnull()]

# %%
df_master = df_master.drop(columns = ['in_reply_to_status_id', 'in_reply_to_user_id'])

# %% [markdown]
# #### Test

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2291 entries, 0 to 2369
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2291 non-null   int64
#  1   timestamp                   2291 non-null   object
#  2   source                      2291 non-null   object
#  3   text                        2291 non-null   object
#  4   retweeted_status_id         183 non-null    float64
#  5   retweeted_status_user_id    183 non-null    float64
#  6   retweeted_status_timestamp  183 non-null    object
#  7   expanded_urls               2287 non-null   object
#  8   rating_numerator            2291 non-null   int64
#  9   rating_denominator          2291 non-null   int64
#  10  name                        2291 non-null   object
#  11  stage                       385 non-null    object
#  12  retweet_count               2266 non-null   float64
# ...

# %% [markdown]
# - **Lines with retweeted status not null are retweets**

# %% [markdown]
# #### Define

# %% [markdown]
# Drop the non-null rows in the columns 'retweeted_status_id', 'retweeted_status_user_id' and 'retweeted_status_timestamp' and then delete those same columns

# %% [markdown]
# #### Code

# %%
df_master = df_master[df_master.retweeted_status_id.isnull()]

# %%
df_master = df_master.drop(columns = ['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'])

# %% [markdown]
# #### Test

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2108 entries, 0 to 2369
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2108 non-null   int64
#  1   timestamp           2108 non-null   object
#  2   source              2108 non-null   object
#  3   text                2108 non-null   object
#  4   expanded_urls       2105 non-null   object
#  5   rating_numerator    2108 non-null   int64
#  6   rating_denominator  2108 non-null   int64
#  7   name                2108 non-null   object
#  8   stage               347 non-null    object
#  9   retweet_count       2101 non-null   float64
#  10  favorite_count      2101 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 197.6+ KB

# %% [markdown]
# - **Names very, quite, incredibly, infuriating and his are not dogs**

# %% [markdown]
# #### Define

# %% [markdown]
# Delete the rows with the names very, remove, incredibly and his, since they are not dogs.

# %% [markdown]
# #### Code

# %%
df_master = df_master[(df_master.name != 'very') & (df_master.name != 'remove')
                      & (df_master.name != 'incredibly') & (df_master.name != 'his')]

# %% [markdown]
# #### Test

# %%
sum(df_master.name == 'very') + sum(df_master.name == 'remove') + sum(df_master.name == 'incredibly') + sum(df_master.name == 'his')
# Out:
# 0

# %% [markdown]
# - **Nan names dogs with name None, a, one, ...**

# %% [markdown]
# #### Define

# %% [markdown]
# Change all the names in wrong_names to NaN as well as a and None names.

# %% [markdown]
# #### Code

# %%
#Check the remaining wrong names in the list after the last quality issue cleaned
wrong_names_master = df_master.name.str.match(r"\b[^A-Z]\w+")
wrong_names_list = df_master[wrong_names_master].name.tolist()
#Introduce 'None' and 'a' names in the list
wrong_names_list.append('None')
wrong_names_list.append('a')

# %%
# Introduce NaN value for each name in the list
for item in wrong_names_list:
    df_master = df_master.replace(item, np.nan)

# %% [markdown]
# #### Test

# %%
df_master['name'].value_counts()
# Out:
# Lucy         11
# Charlie      11
# Cooper       10
# Oliver       10
# Tucker        9
#              ..
# Bookstore     1
# Rumpole       1
# Huck          1
# Kellogg       1
# Eevee         1
# Name: name, Length: 929, dtype: int64

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2102 entries, 0 to 2369
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2102 non-null   int64
#  1   timestamp           2102 non-null   object
#  2   source              2102 non-null   object
#  3   text                2102 non-null   object
#  4   expanded_urls       2099 non-null   object
#  5   rating_numerator    2102 non-null   int64
#  6   rating_denominator  2102 non-null   int64
#  7   name                1394 non-null   object
#  8   stage               346 non-null    object
#  9   retweet_count       2095 non-null   float64
#  10  favorite_count      2095 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 197.1+ KB

# %% [markdown]
# - **timestamp column is a string**

# %% [markdown]
# #### Define

# %% [markdown]
# Change the data type of the timestamp column to datetime

# %% [markdown]
# #### Code

# %%
df_master.timestamp = pd.to_datetime(df_master.timestamp)

# %% [markdown]
# #### Test

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2102 entries, 0 to 2369
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2102 non-null   int64
#  1   timestamp           2102 non-null   datetime64[ns, UTC]
#  2   source              2102 non-null   object
#  3   text                2102 non-null   object
#  4   expanded_urls       2099 non-null   object
#  5   rating_numerator    2102 non-null   int64
#  6   rating_denominator  2102 non-null   int64
#  7   name                1394 non-null   object
#  8   stage               346 non-null    object
#  9   retweet_count       2095 non-null   float64
#  10  favorite_count      2095 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(2), int64(3), object(5)
# memory usage: 197.1+ KB

# %% [markdown]
# - **There should be an extra column showing the actual rating without differences in the denominators**

# %% [markdown]
# #### Define

# %% [markdown]
# Create a new column with the result of the division of the columns rating_numerator and rating_denominator

# %% [markdown]
# #### Code

# %%
df_master['rating'] = df_master['rating_numerator']/df_master['rating_denominator']

# %% [markdown]
# #### Test

# %%
df_master.head(2)
# Out:
#              tweet_id                 timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00
# 1  892177421306343426 2017-08-01 00:17:27+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name stage  retweet_count  favorite_count  rating
# 0                  10  Phineas   NaN         7455.0         35310.0     1.3
# 1                  10    Tilly   NaN         5535.0         30551.0     1.3

# %% [markdown]
# - **Tweet id 765395769549590528 name is Zoey**

# %% [markdown]
# #### Define

# %% [markdown]
# Change the name of the tweet id 765395769549590528 to Zoey

# %% [markdown]
# #### Code

# %%
df_master.loc[862, 'name'] = 'Zoey'

# %% [markdown]
# #### Test

# %%
df_master[df_master.tweet_id == 765395769549590528]
# Out:
#                tweet_id                 timestamp  \
# 862  765395769549590528 2016-08-16 03:52:26+00:00
#
#                                                 source  \
# 862  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  \
# 862  This is my dog. Her name is Zoey. She knows I'...
#
#                                          expanded_urls  rating_numerator  \
# 862  https://twitter.com/dog_rates/status/765395769...                13
#
#      rating_denominator  name stage  retweet_count  favorite_count  rating
# 862                  10  Zoey   NaN         3324.0         26247.0     1.3

# %% [markdown]
# - **Tweet_id 878604707211726852 name is Martha**

# %% [markdown]
# #### Define

# %% [markdown]
# Change the name of the tweet id 878604707211726852 to Martha

# %% [markdown]
# #### Code

# %%
df_master.loc[72, 'name'] = 'Martha'

# %% [markdown]
# #### Test

# %%
df_master[df_master.tweet_id == 878604707211726852]
# Out:
#               tweet_id                 timestamp  \
# 72  878604707211726852 2017-06-24 13:24:20+00:00
#
#                                                source  \
# 72  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  \
# 72  Martha is stunning how h*ckin dare you. 13/10 ...
#
#                                         expanded_urls  rating_numerator  \
# 72  https://twitter.com/bbcworld/status/8785998685...                13
#
#     rating_denominator    name stage  retweet_count  favorite_count  rating
# 72                  10  Martha   NaN         6255.0         27587.0     1.3

# %% [markdown]
# - **Source column has html tags**

# %% [markdown]
# #### Define

# %% [markdown]
# Remove the html tags and the web address of the column source

# %% [markdown]
# #### Code

# %%
df_master.source.unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'],
#       dtype=object)

# %%
df_master.source = df_master.source.str.replace(r'(^<.+".)', '')
df_master.source = df_master.source.str.replace(r'<.+', '')
# Out:
# 0       Twitter for iPhone
# 1       Twitter for iPhone
# 2       Twitter for iPhone
# 3       Twitter for iPhone
# 4       Twitter for iPhone
#                ...
# 2365    Twitter for iPhone
# 2366    Twitter for iPhone
# 2367    Twitter for iPhone
# 2368    Twitter for iPhone
# 2369    Twitter for iPhone
# Name: source, Length: 2102, dtype: object

# %% [markdown]
# #### Test

# %%
df_master.source.unique()
# Out:
# array(['Twitter for iPhone', 'Twitter Web Client', 'Vine - Make a Scene',
#        'TweetDeck'], dtype=object)

# %% [markdown]
# ## Data Analysis

# %%
df_master.head()
# Out:
#              tweet_id                 timestamp              source  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2  891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3  891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4  891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# ...

# %%
df_predictions_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ### Rating, retweet and favourite count distribution by stage

# %%
temp1 = df_master[['stage', 'retweet_count', 'favorite_count', 'rating']]
temp1 = temp1[temp1.stage.notnull()]

# %%
temp1.stage.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = [12, 6])

plt.subplot(1, 3, 1)
sns.boxplot(x=temp1["stage"], y=temp1['rating'], showfliers = False).set(xlabel = None, ylabel = None)
plt.title('Dog Stage vs. Rating')

plt.subplot(1, 3, 2)
sns.boxplot(x=temp1["stage"], y=temp1['favorite_count'], showfliers = False).set(xlabel = None, ylabel = None)
plt.title('Dog Stage vs. Favorites')

plt.subplot(1, 3, 3)
sns.boxplot(x=temp1["stage"], y=temp1['retweet_count'], showfliers = False).set(xlabel = None, ylabel = None)
plt.title('Dog Stage vs. Retweet')
plt.tight_layout()

# %% [markdown]
# **The data shows that the best rated dog stage is the puppo one, as it shows a greater number of both, retweets and favourites, closely followed by the doggo stage. As for the rating given by the WeRateDogs Twitter account, both doggo and puppo have the same average.**

# %% [markdown]
# ### Time and source

# %%
temp2 = df_master[['timestamp', 'source']]

# %%
fig = plt.figure(figsize = [15, 8])
sizes = temp2.source.value_counts()
plt.pie(sizes, autopct='%1.1f%%', pctdistance=1.15)
plt.legend(sizes.index, bbox_to_anchor=(1, 0.65), fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **The vast majority of tweets from the WeRateDogs account, 93.6%, have been made from the Twitter App for iPhone.**

# %%
temp2['hours'] = temp2.timestamp.dt.hour
time_bins = [-1, 5, 11, 17, 23]
temp2['binned_hours'] = pd.cut(temp2.hours, bins=time_bins)
# Out:
# <ipython-input-224-84f658b85912>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp2['hours'] = temp2.timestamp.dt.hour
# <ipython-input-224-84f658b85912>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp2['binned_hours'] = pd.cut(temp2.hours, bins=time_bins)

# %%
fig = plt.figure(figsize = [15, 8])
sizes2 = temp2.binned_hours.value_counts()
plt.pie(sizes2, autopct='%1.1f%%', pctdistance=1.15)
plt.legend(sizes2.index, bbox_to_anchor=(1, 0.65), fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **More than half of the tweets on the account, 51.3%, have been posted between 0 am and 6 am and between 6 am and 12 pm, only 0.2% have been posted. Indicating that the account owner is a night person.**
